# %%
import numpy as np
import cv2 as cv
import matplotlib.pyplot as plt
from skimage.metrics import structural_similarity as ssim
import urllib

# %%
req = urllib.request.urlopen('https://raw.githubusercontent.com/opencv/opencv/master/samples/data/messi5.jpg')
arr = np.asarray(bytearray(req.read()), dtype=np.uint8)
img = cv.imdecode(arr, cv.IMREAD_COLOR ) # 'Load it as grayscale'
img_o = img.copy()

# %%
mask = np.zeros(img.shape[:2],np.uint8)
bgdModel = np.zeros((1,65),np.float64)
fgdModel = np.zeros((1,65),np.float64)
rect = (50,50,450,290)
cv.grabCut(img,mask,rect,bgdModel,fgdModel,5,cv.GC_INIT_WITH_RECT)
mask2 = np.where((mask==2)|(mask==0),0,1).astype('uint8')
plt.imshow(img_o)
img = img*mask2[:,:,np.newaxis]
plt.figure()
plt.imshow(img),plt.colorbar(),plt.show()
# Out:
# (<matplotlib.image.AxesImage at 0x7fdbf06d4460>,
#  <matplotlib.colorbar.Colorbar at 0x7fdbf0701d90>,
#  None)

# %% [markdown]
# https://docs.opencv.org/3.4/d8/d83/tutorial_py_grabcut.html
